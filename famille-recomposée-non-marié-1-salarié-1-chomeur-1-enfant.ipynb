# %%
from __future__ import division

import collections
import copy
import json
import urllib2

# %%
test_case = dict(
    familles = [
        dict(
            parents = ['ind0', 'ind1'],
            enfants = ['ind2'],
            ),
        ],
    foyers_fiscaux = [
        dict(
            declarants = ['ind0'],
            personnes_a_charge = ['ind2'],
            ),
        dict(
            declarants = ['ind1'],
            ),
        ],
    individus = [
        dict(
            activite = u'Actif occupé',
            birth = 1970,
            id = 'ind0',
            statmarit = u'Divorcé',
            ),
        dict(
            activite = u'Chômeur',
            birth = 1970,
            id = 'ind1',
            statmarit = u'Célibataire',
            ),
        dict(
            activite = u'Étudiant, élève',
            birth = 2000,
            id = 'ind2',
            ),
        ],
    menages = [
        dict(
            personne_de_reference = 'ind0',
            conjoint = 'ind1',
            enfants = ['ind2'],
            ),
        ],
    )
years = [2013]

# %%
scenarios = [
    dict(
        axes = [
            dict(
                index = 1,
                count = 3,
                max = 16000,
                min = 0,
                name = 'sali',
                ),
            dict(
                index = 2,
                count = 3,
                max = 12000,
                min = 0,
                name = 'sali',
                ),
            ],
        legislation_url = 'http://localhost:2014/api/1/default-legislation',
        test_case = test_case,
        year = year,
        )
    for year in years
    ]
simulation = dict(
    scenarios = scenarios,
    tax_benefit_system = None,
    )

# %%
request = urllib2.Request('http://localhost:2014/api/1/simulate', headers = {
    'Content-Type': 'application/json',
    'User-Agent': 'OpenFisca-Notebook',
    })
try:
    response = urllib2.urlopen(request, json.dumps(simulation))
except urllib2.HTTPError as response:
    print response.read()
    raise
response_text = response.read()
response_dict = json.loads(response_text, object_pairs_hook = collections.OrderedDict)
tree = response_dict['value']

# %%
def any(iterator):
    for item in iterator:
        if item:
            return True
    return False

def iter_columns_from_tree(node, base_values = None):
    children = node.get('children')
    if children:
        child_base_values = base_values
        for child in children:
            for column in iter_columns_from_tree(child, base_values = child_base_values):
                yield column
            if child_base_values is None:
                child_base_values = child['values']
            else:
                child_base_values = [
                    base_value + value
                    for base_value, value in zip(child_base_values, child['values'])
                    ]

    if any(value != 0 for value in node['values']):
        column = dict(
            base_values = base_values,
            code = node['code'],
            )
        column.update(node)
        yield column

# %%
for column_index, column in enumerate(iter_columns_from_tree(tree)):
    print u'{:40s} | {}'.format(column['name'], ' | '.join('{:6.0f}'.format(value) for value in column['values']))
# Out:
# Salaires super bruts                     |      0 |  11083 |  24073 |   8312 |  19396 |  32385 |  16625 |  27708 |  40698
# Cotisations sociales patronales          |      0 |  -4393 |  -8785 |  -3295 |  -7687 | -12080 |  -6589 | -10982 | -15374
# Allègement sur les bas salaires (Fillon) |      0 |   2769 |   3631 |   2077 |   4845 |   5708 |   4153 |   6922 |   7785
# Crédit d'impôt compétitivité-emploi      |      0 |    394 |    788 |    296 |    690 |   1084 |    591 |    985 |   1379
# Salaires bruts                           |      0 |   9854 |  19707 |   7390 |  17244 |  27097 |  14780 |  24634 |  34487
# Cotisations sociales salariées           |      0 |  -1360 |  -2720 |  -1020 |  -2380 |  -3739 |  -2040 |  -3399 |  -4759
# CSG déductible (salaires)                |      0 |   -494 |   -987 |   -370 |   -864 |  -1358 |   -741 |  -1234 |  -1728
# Salaires imposables                      |      0 |   8000 |  16000 |   6000 |  14000 |  22000 |  12000 |  20000 |  28000
# CSG non déductible (salaires)            |      0 |   -232 |   -465 |   -174 |   -407 |   -639 |   -349 |   -581 |   -813
# CRDS (salaires)                          |      0 |    -48 |    -97 |    -36 |    -85 |   -133 |    -73 |   -121 |   -169
# Salaires nets                            |      0 |   7719 |  15438 |   5789 |  13509 |  21228 |  11579 |  19298 |  27017
# Revenu du travail                        |      0 |   7719 |  15438 |   5789 |  13509 |  21228 |  11579 |  19298 |  27017
# Revenus nets                             |      0 |   7719 |  15438 |   5789 |  13509 |  21228 |  11579 |  19298 |  27017
# Allocation de rentrée scolaire           |    378 |    378 |    378 |    378 |    378 |    378 |      0 |      0 |      0
# CRDS (prestations familiales)            |     -2 |     -2 |     -2 |     -2 |     -2 |     -2 |      0 |      0 |      0
# Prestations familiales                   |    376 |    376 |    376 |    376 |    376 |    376 |      0 |      0 |      0
# Revenu de solidarité active              |   8716 |   5676 |   2636 |   8716 |   5676 |   2636 |   7307 |   4267 |   1227
# Aide exceptionelle de fin d'année        |    274 |    274 |    274 |    274 |    274 |    274 |    229 |    229 |    229
# Minima sociaux                           |   8990 |   5950 |   2910 |   8990 |   5950 |   2910 |   7535 |   4495 |   1455
# Prestations sociales                     |   9366 |   6326 |   3286 |   9366 |   6326 |   3286 |   7535 |   4495 |   1455
# Impôt sur le revenu                      |      0 |      0 |   -491 |      0 |      0 |   -491 |      0 |      0 |   -491
# Impôts directs                           |      0 |      0 |   -491 |      0 |      0 |   -491 |      0 |      0 |   -491
# Revenu disponible                        |   9366 |  14045 |  18233 |  15155 |  19835 |  24023 |  19114 |  23793 |  27981
