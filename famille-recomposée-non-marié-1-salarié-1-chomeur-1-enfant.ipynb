# %%
from __future__ import division

import collections
import copy
import json
import urllib2

# %%
test_case = dict(
    familles = [
        dict(
            parents = ['ind0', 'ind1'],
            enfants = ['ind2'],
        ),
    ],
    foyers_fiscaux = [
        dict(
            declarants = ['ind0'],
            personnes_a_charge = ['ind2'],
        ),
        dict(
            declarants = ['ind1'],
        ),
    ],
    individus = [
        dict(
            activite = u'Actif occupé',
            birth = 1970,
            id = 'ind0',
            statmarit = u'Divorcé',
            ),
        dict(
            activite = u'Chômeur',
            birth = 1970,
            id = 'ind1',
            statmarit = u'Célibataire',
            ),
        dict(
            activite = u'Étudiant, élève',
            birth = 2000,
            id = 'ind2',
            ),
        ],
    menages = [
        dict(
            personne_de_reference = 'ind0',
            conjoint = 'ind1',
            enfants = ['ind2'],
        ),
    ],
)
years = [2013]

# %%
scenarios = [
    dict(
        axes = [
            dict(
                index = 0,
                count = 3,
                max = 30000,
                min = 0,
                name = 'sali',
                ),
            dict(
                index = 1,
                count = 3,
                max = 12000,
                min = 0,
                name = 'sali',
                ),
            ],
        legislation_url = 'http://api.openfisca.fr/api/1/default-legislation',
        test_case = test_case,
        year = year,
        )
    for year in years
    ]
simulation = dict(
    scenarios = scenarios,
    tax_benefit_system = None,
    )

# %%
request = urllib2.Request('http://api.openfisca.fr/api/1/simulate', headers = {
    'Content-Type': 'application/json',
    'User-Agent': 'OpenFisca-Notebook',
    })
try:
    response = urllib2.urlopen(request, json.dumps(simulation))
except urllib2.HTTPError as response:
    print response.read()
    raise
response_text = response.read()
response_dict = json.loads(response_text, object_pairs_hook = collections.OrderedDict)
tree = response_dict['value']

# %%
def any(iterator):
    for item in iterator:
        if item:
            return True
    return False

def iter_columns_from_tree(node, base_values = None):
    children = node.get('children')
    if children:
        child_base_values = base_values
        for child in children:
            for column in iter_columns_from_tree(child, base_values = child_base_values):
                yield column
            if child_base_values is None:
                child_base_values = child['values']
            else:
                child_base_values = [
                    base_value + value
                    for base_value, value in zip(child_base_values, child['values'])
                    ]

    if any(value != 0 for value in node['values']):
        column = dict(
            base_values = base_values,
            code = node['code'],
            )
        column.update(node)
        yield column

# %%
for column_index, column in enumerate(iter_columns_from_tree(tree)):
    print u'{:40s} | {}'.format(column['name'], ' | '.join('{:6.0f}'.format(value) for value in column['values']))
# Out:
# Salaires super bruts                     |      0 |  21764 |  51945 |   8312 |  30077 |  60258 |  16625 |  38389 |  68570
# Cotisations sociales patronales          |      0 |  -8236 | -16473 |  -3295 | -11531 | -19767 |  -6589 | -14825 | -23062
# Allègement sur les bas salaires (Fillon) |      0 |   4208 |      0 |   2077 |   6285 |   2077 |   4153 |   8361 |   4153
# Crédit d'impôt compétitivité-emploi      |      0 |    739 |   1478 |    296 |   1035 |   1774 |    591 |   1330 |   2069
# Salaires bruts                           |      0 |  18475 |  36951 |   7390 |  25865 |  44341 |  14780 |  33256 |  51731
# Cotisations sociales salariées           |      0 |  -2550 |  -5099 |  -1020 |  -3569 |  -6119 |  -2040 |  -4589 |  -7139
# CSG déductible (salaires)                |      0 |   -926 |  -1852 |   -370 |  -1296 |  -2222 |   -741 |  -1666 |  -2592
# Salaires imposables                      |      0 |  15000 |  30000 |   6000 |  21000 |  36000 |  12000 |  27000 |  42000
# CSG non déductible (salaires)            |      0 |   -436 |   -871 |   -174 |   -610 |  -1046 |   -349 |   -784 |  -1220
# CRDS (salaires)                          |      0 |    -91 |   -182 |    -36 |   -127 |   -218 |    -73 |   -163 |   -254
# Salaires nets                            |      0 |  14474 |  28947 |   5789 |  20263 |  34737 |  11579 |  26052 |  40526
# Revenu du travail                        |      0 |  14474 |  28947 |   5789 |  20263 |  34737 |  11579 |  26052 |  40526
# Revenus nets                             |      0 |  14474 |  28947 |   5789 |  20263 |  34737 |  11579 |  26052 |  40526
# Allocation de rentrée scolaire           |    378 |    378 |      0 |    378 |    378 |      0 |    378 |      0 |      0
# CRDS (prestations familiales)            |     -2 |     -2 |      0 |     -2 |     -2 |      0 |     -2 |      0 |      0
# Prestations familiales                   |    376 |    376 |      0 |    376 |    376 |      0 |    376 |      0 |      0
# Revenu de solidarité active              |   8716 |   3016 |      0 |   6436 |    736 |      0 |   4156 |      0 |      0
# Aide exceptionelle de fin d'année        |    274 |    274 |      0 |    274 |    274 |      0 |    274 |      0 |      0
# Minima sociaux                           |   8990 |   3290 |      0 |   6710 |   1010 |      0 |   4430 |      0 |      0
# Prestations sociales                     |   9366 |   3666 |      0 |   7086 |   1386 |      0 |   4806 |      0 |      0
# Impôt sur le revenu                      |      0 |   -302 |  -2489 |      0 |   -302 |  -2489 |      0 |   -302 |  -2489
# Impôts directs                           |      0 |   -302 |  -2489 |      0 |   -302 |  -2489 |      0 |   -302 |  -2489
# Revenu disponible                        |   9366 |  17837 |  26458 |  12875 |  21347 |  32247 |  16385 |  25750 |  38037
