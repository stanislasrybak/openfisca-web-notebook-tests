# %%
from __future__ import division

import collections
import copy
import json
import urllib2

# %%
test_case = dict(
    familles = [
        dict(
            parents = ['ind0', 'ind1'],
            enfants = ['ind2', 'ind3'],
            ),
        ],
    foyers_fiscaux = [
        dict(
            declarants = ['ind0', 'ind1'],
            personnes_a_charge = ['ind2', 'ind3'],
            ),
        ],
    individus = [
        dict(
            activite = u'Retraité',
            birth = 1940,
            id = 'ind0',
            statmarit = u'Marié',
            ),
        dict(
            activite = u'Retraité',
            birth = 1940,
            id = 'ind1',
            statmarit = u'Marié',
            ),
        dict(
            activite = u'Étudiant, élève',
            birth = '1992-02-01',
            id = 'ind2',
            ),
        dict(
            activite = u'Étudiant, élève',
            birth = '1990-04-17',
            id = 'ind3',
            ),
        ],
    menages = [
        dict(
            personne_de_reference = 'ind0',
            conjoint = 'ind1',
            enfants = ['ind2', 'ind3'],
            loyer = 500,
            code_postal = 69001,
            zthabm = 0,
            so = 4,
            zone_apl = 2,
            ),
        ],
    )
years = [2013]

# %%
scenarios = [
    dict(
        axes = [
            dict(
                index = 1,
                count = 2,
                max = 12500,
                min = 0,
                name = 'sali',
                ),
            dict(
                index = 2,
                count = 2,
                max = 12500,
                min = 0,
                name = 'sali',
                ),
            ],
        legislation_url = 'http://api.openfisca.fr/api/1/default-legislation',
        test_case = test_case,
        year = year,
        )
    for year in years
    ]
simulation = dict(
    scenarios = scenarios,
    tax_benefit_system = None,
    )

# %%
request = urllib2.Request('http://api.openfisca.fr/api/1/simulate', headers = {
    'Content-Type': 'application/json',
    'User-Agent': 'OpenFisca-Notebook',
    })
try:
    response = urllib2.urlopen(request, json.dumps(simulation))
except urllib2.HTTPError as response:
    print response.read()
    raise
response_text = response.read()
response_dict = json.loads(response_text, object_pairs_hook = collections.OrderedDict)
tree = response_dict['value']

# %%
def any(iterator):
    for item in iterator:
        if item:
            return True
    return False

def iter_columns_from_tree(node, base_values = None):
    children = node.get('children')
    if children:
        child_base_values = base_values
        for child in children:
            for column in iter_columns_from_tree(child, base_values = child_base_values):
                yield column
            if child_base_values is None:
                child_base_values = child['values']
            else:
                child_base_values = [
                    base_value + value
                    for base_value, value in zip(child_base_values, child['values'])
                    ]

    if any(value != 0 for value in node['values']):
        column = dict(
            base_values = base_values,
            code = node['code'],
            )
        column.update(node)
        yield column

# %%
for column_index, column in enumerate(iter_columns_from_tree(tree)):
    print u'{:40s} | {}'.format(column['name'], ' | '.join('{:6.0f}'.format(value) for value in column['values']))
# Out:
# Salaires super bruts                     |      0 |  17318 |  17318 |  34635
# Cotisations sociales patronales          |      0 |  -6864 |  -6864 | -13727
# Allègement sur les bas salaires (Fillon) |      0 |   4326 |   4326 |   8653
# Crédit d'impôt compétitivité-emploi      |      0 |    616 |    616 |   1232
# Salaires bruts                           |      0 |  15396 |  15396 |  30792
# Cotisations sociales salariées           |      0 |  -2125 |  -2125 |  -4249
# CSG déductible (salaires)                |      0 |   -771 |   -771 |  -1543
# Salaires imposables                      |      0 |  12500 |  12500 |  25000
# CSG non déductible (salaires)            |      0 |   -363 |   -363 |   -726
# CRDS (salaires)                          |      0 |    -76 |    -76 |   -151
# Salaires nets                            |      0 |  12061 |  12061 |  24123
# Revenu du travail                        |      0 |  12061 |  12061 |  24123
# Revenus nets                             |      0 |  12061 |  12061 |  24123
# Minimum vieillesse                       |  14479 |      0 |  14479 |      0
# Revenu de solidarité active              |      0 |   5705 |      0 |   3966
# Aide exceptionelle de fin d'année        |      0 |    229 |      0 |    229
# Minima sociaux                           |  14479 |   5934 |  14479 |   4194
# Allocation logement social               |      0 |      0 |   3945 |   2849
# Allocation de logement familiale         |   4548 |   4548 |      0 |      0
# CRDS (allocation logement)               |    -23 |    -23 |    -20 |    -14
# Prestations logement                     |   4525 |   4525 |   3926 |   2834
# Prestations sociales                     |  19004 |  10459 |  18405 |   7029
# Impôt sur le revenu                      |      0 |      0 |      0 |   -164
# Impôts directs                           |      0 |      0 |      0 |   -164
# Revenu disponible                        |  19004 |  22520 |  30466 |  30987
